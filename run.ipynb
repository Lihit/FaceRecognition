# %%
# %run AlexnetTrain.py
# Out:
# The number of class is:376
# The number of Training image:39774
# The number of testing image:4801
# The number of validation image:4957
# ===================== Start Training ====================>
# Step:0  Validation on random sample:100 =====>Accuracy:0.00%  Loss:5.93
# Step:100  Validation on random sample:100 =====>Accuracy:0.00%  Loss:5.93
# Step:200  Validation on random sample:100 =====>Accuracy:0.00%  Loss:5.80
# Step:300  Validation on random sample:100 =====>Accuracy:1.00%  Loss:5.74
# Step:400  Validation on random sample:100 =====>Accuracy:2.00%  Loss:5.42
# Step:500  Validation on random sample:100 =====>Accuracy:3.00%  Loss:4.94
# Step:600  Validation on random sample:100 =====>Accuracy:9.00%  Loss:4.76
# Step:700  Validation on random sample:100 =====>Accuracy:9.00%  Loss:4.73
# Step:800  Validation on random sample:100 =====>Accuracy:19.00%  Loss:4.07
# Step:900  Validation on random sample:100 =====>Accuracy:20.00%  Loss:4.06
# ...

# %%
# %run AlexnetTrain.py
# Out:
# The number of class is:376
# The number of Training image:39774
# The number of testing image:4801
# The number of validation image:4957
# ===================== Start Training ====================>
# 2017-07-18 00:41:14  Step:0  Validation on random sample:100 =====>Accuracy:0.00%  Loss:5.93
# 2017-07-18 00:42:53  Step:100  Validation on random sample:100 =====>Accuracy:0.00%  Loss:5.92
# 2017-07-18 00:44:55  Step:200  Validation on random sample:100 =====>Accuracy:1.00%  Loss:5.82
# 2017-07-18 00:47:32  Step:300  Validation on random sample:100 =====>Accuracy:1.00%  Loss:5.59
# 2017-07-18 00:50:44  Step:400  Validation on random sample:100 =====>Accuracy:5.00%  Loss:5.22
# 2017-07-18 00:54:27  Step:500  Validation on random sample:100 =====>Accuracy:6.00%  Loss:4.93
# 2017-07-18 00:58:46  Step:600  Validation on random sample:100 =====>Accuracy:7.00%  Loss:4.72
# 2017-07-18 01:03:40  Step:700  Validation on random sample:100 =====>Accuracy:18.00%  Loss:4.14
# ...
